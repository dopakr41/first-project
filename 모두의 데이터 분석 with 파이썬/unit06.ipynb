# %%
import matplotlib.pyplot as plt
plt.hist([1,1,2,3,4,5,6,6,7,8,10])
plt.show()

# %% [markdown]
# ## 주사위 시물레이션
# 기온 데이터를 히스토그램 형태로 시각화하기에 앞서 히스토그램 표현을 연습해 보겠습니다.
# 임의의 수를 뽑는 랜덤 함수를 활용해 간단한 주사위 시뮬레이션을 만들겠습니다.

# %% [markdown]
# 1. 주사위를 굴린다.
# 2. 나온 결과를 기록한다.
# 3. 1~2과정을 n번 반복한다.
# 4. 주사위의 눈이 나온 횟수를 히스토그램으로  그린다.

# %%
import random
print(random.randint(1, 6))
# Out:
# 3

# %%
dice=[]
for i in range(5):
    dice.append(random.randint(1,6))
print(dice)
# Out:
# [2, 3, 4, 5, 4]

# %%
import matplotlib.pyplot as plt
plt.hist(dice, bins=6)
plt.show()

# %%
dice = []
for i in range(100):
    dice.append(random.randint(1,6))
plt.hist(dice, bins=6)
plt.show()

# %%
dice = []
for i in range(1000000):
    dice.append(random.randint(1,6))
plt.hist(dice, bins=6)
plt.show()

# %% [markdown]
# # 기온 데이터를 히스토그램으로 표현하기

# %%
import csv
import matplotlib.pyplot as plt

f = open('seoul.csv')
data = csv.reader(f)
next(data)
result=[]

for row in data:
    if row[-1] !='':
        result.append(float(row[-1]))

plt.hist(result,bins=100, color='r') # 히스토그램으로 나타내기
plt.show()

# %% [markdown]
# ## #8월 데이터만 뽑아서 히스토그램 그리기

# %%
import csv
import matplotlib.pyplot as plt
 
f = open('seoul.csv')
data = csv.reader(f)
next(data)
aug = []                          # 8월의 최고 기온 값을 저장할 aug 리스트 생성

for row in data :
    month = row[0].split('-')[1]  # -로 구분된 값 중 2번째 값을 month에 저장
    if row[-1] != '' :
        if month == '08':               # 8월달이라면
            aug.append(float(row[-1]))  # aug 리스트에 최고 기온 값 추가

plt.hist(aug, bins=100, color='r')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [22], line 10
#       7 aug = []                          # 8월의 최고 기온 값을 저장할 aug 리스트 생성
#       9 for row in data :
# ---> 10     month = row[0].split('-')[1]  # -로 구분된 값 중 2번째 값을 month에 저장
#      11     if row[-1] != '' :
#      12         if month == '08':               # 8월달이라면
#
# IndexError: list index out of range
