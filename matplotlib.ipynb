# %%
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd

matplotlib.rcParams['font.family'] = 'NanumGothic' # Windows  나눔고딕
# matplotlib.rcParams['font.family'] = 'AppleGothic' # Mac
matplotlib.rcParams['font.size'] = 15 # 글자 크기
matplotlib.rcParams['axes.unicode_minus'] = False # 한글 폰트 사용 시, 마이너스 글자가 깨지는 현상을 해결

# %%
plt.plot([1,2,3,4], 'b^--')
plt.show()

# %%
data = pd.read_csv('../data/plotStyleData.csv', header=None)

print(data)
[출처] Python - matplotlib 패키지 1|작성자 다다
# Out:
#   Cell In [13], line 4
#     [출처] Python - matplotlib 패키지 1|작성자 다다
#          ^
# SyntaxError: invalid syntax
