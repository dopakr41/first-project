# %% [markdown]
# # Matplotlib (맷플롯립)
# 다양한 형태의 그래프를 통해서 데이터 시각화를 할 수 있는 라이브러리

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. 그래프 기본

# %%
x = [1, 2, 3]
y = [2, 4, 8]
plt.plot(x, y)

# %%
print(plt.plot(x, y))
# Out:
# [<matplotlib.lines.Line2D object at 0x000001AF2DFC0970>]

# %%
plt.plot(x, y)
plt.show()

# %% [markdown]
# ## Title 설정

# %%
plt.plot(x, y)
plt.title('Line Graph')
# Out:
# Text(0.5, 1.0, 'Line Graph')

# %% [markdown]
# ## 한글 폰트 설정

# %%
import matplotlib
matplotlib.rcParams['font.family'] = 'NanumMyeongjo' # Windows  나눔명조
# matplotlib.rcParams['font.family'] = 'AppleGothic' # Mac
matplotlib.rcParams['font.size'] = 15 # 글자 크기
matplotlib.rcParams['axes.unicode_minus'] = False # 한글 폰트 사용 시, 마이너스 글자가 깨지는 현상을 해결

# %%
import matplotlib.font_manager as fm
fm.fontManager.ttflist # 사용 가능한 폰트 목록 확인
[f.name for f in fm.fontManager.ttflist]
# Out:
# ['cmr10',
#  'STIXSizeTwoSym',
#  'STIXGeneral',
#  'STIXGeneral',
#  'cmtt10',
#  'STIXSizeTwoSym',
#  'cmmi10',
#  'DejaVu Sans Mono',
#  'DejaVu Sans',
#  'DejaVu Serif Display',
#  'STIXNonUnicode',
#  'DejaVu Sans Mono',
#  'DejaVu Sans Mono',
#  'DejaVu Sans',
#  'STIXSizeThreeSym',
#  'STIXSizeOneSym',
#  'DejaVu Serif',
#  'cmss10',
#  'STIXSizeFourSym',
#  'DejaVu Serif',
#  'cmsy10',
#  'DejaVu Serif',
#  'cmex10',
#  'DejaVu Sans Display',
#  'cmb10',
#  'DejaVu Serif',
#  'DejaVu Sans',
#  'STIXNonUnicode',
#  'DejaVu Sans',
#  'STIXNonUnicode',
#  'STIXSizeFiveSym',
#  'STIXSizeFourSym',
#  'STIXSizeThreeSym',
#  'STIXGeneral',
#  'DejaVu Sans Mono',
#  'STIXGeneral',
#  'STIXNonUnicode',
#  'STIXSizeOneSym',
#  'Batang',
#  'Corbel',
#  'HYGraphic-Medium',
#  'Tahoma',
#  'Lucida Fax',
#  'ScriptS',
#  'MS Gothic',
#  'Bauhaus 93',
#  'Century',
#  'Calisto MT',
#  'French Script MT',
#  'Candara',
#  'Sylfaen',
#  'MV Boli',
#  'Calisto MT',
#  'Ink Free',
#  'Segoe UI Historic',
#  'Script MT Bold',
#  'CountryBlueprint',
#  'Lucida Sans',
#  'Corbel',
#  'IDAutomationSC128M DEMO',
#  'UPC-A',
#  'NanumSquare',
#  'Swis721 LtEx BT',
#  'Arial',
#  'Edwardian Script ITC',
#  'HYSinMyeongJo-Medium',
#  'Elephant',
#  'Segoe UI',
#  'Microsoft JhengHei',
#  'Arial',
#  'Yu Gothic',
#  'Garamond',
#  'Gulim',
#  'Times New Roman',
#  'Swis721 BT',
#  'Monospac821 BT',
#  'MingLiU-ExtB',
#  'NanumGothic',
#  'Haettenschweiler',
#  'Nanum GoDigANiGoGoDing',
#  'Chiller',
#  'HYHeadLine-Medium',
#  'Viner Hand ITC',
#  'New Gulim',
#  'TechnicLite',
#  'Symusic',
#  'HYShortSamul-Medium',
#  'UniversalMath1 BT',
#  'Microsoft Yi Baiti',
#  'Eras Medium ITC',
#  'Proxy 2',
#  'Swis721 BlkCn BT',
#  'TechnicBold',
#  'Old English Text MT',
#  'HYPost-Medium',
#  'MS Outlook',
#  'NanumBarunGothic YetHangul',
#  'Arial',
#  'NanumBarunGothic',
#  'Noto Sans KR',
#  'Times New Roman',
#  'Centaur',
#  'Courier New',
#  'Microsoft New Tai Lue',
#  'TechnicBold',
#  'CountryBlueprint',
#  'Segoe UI',
#  'Swis721 BlkOul BT',
#  'OCR A Extended',
#  'Ebrima',
#  'Proxy 7',
#  'SansSerif',
#  'Lucida Sans Unicode',
#  'Magic R',
#  'Microsoft Tai Le',
#  'Calibri',
#  'Malgun Gothic',
#  'Candara',
#  'NanumGothic',
#  'Felix Titling',
#  'Courier New',
#  'Castellar',
#  'MS Outlook',
#  'AmdtSymbols',
#  'Lucida Sans',
#  'Wide Latin',
#  'Segoe UI',
#  'Microsoft YaHei',
#  'Vladimir Script',
#  'Swis721 BlkEx BT',
#  'Lucida Bright',
#  'Cambria',
#  'Onyx',
#  'BankGothic Lt BT',
#  'Segoe MDL2 Assets',
#  'Code 128',
#  'Gill Sans MT',
#  'Book Antiqua',
#  'Times New Roman',
#  'Perpetua Titling MT',
#  'Gadugi',
#  'Curlz MT',
#  'HYSinMyeongJo-Medium',
#  'Centaur',
#  'High Tower Text',
#  'Cambria',
#  'Rockwell',
#  'Forte',
#  'Nirmala UI',
#  'HYGothic-Extra',
#  'Bauhaus 93',
#  'Italic',
#  'Corbel',
#  'Dubai',
#  'Proxy 8',
#  'Maiandra GD',
#  'Bodoni MT',
#  'Franklin Gothic Medium',
#  'Sitka Small',
#  'NanumBarunpen',
#  'Lucida Handwriting',
#  'Bookman Old Style',
#  'Freestyle Script',
#  'Segoe Print',
#  'Verdana',
#  'Mongolian Baiti',
#  'Trebuchet MS',
#  'Kristen ITC',
#  'Bodoni MT',
#  'Bodoni MT',
#  'Century',
#  'HoloLens MDL2 Assets',
#  'Calibri',
#  'Comic Sans MS',
#  'Cambria',
#  'Black Han Sans',
#  'QR font tfb',
#  'Copperplate Gothic Bold',
#  'GreekS',
#  'Kristen ITC',
#  'Berlin Sans FB',
#  'Bradley Hand ITC',
#  'Tw Cen MT',
#  'Papyrus',
#  'Mongolian Baiti',
#  'NanumSquare',
#  'Lucida Fax',
#  'HYGungSo-Bold',
#  'Lucida Sans',
#  'Monotype Corsiva',
#  'Free 3 of 9',
#  'Segoe UI',
#  'Bodoni MT',
#  'Bell MT',
#  'Yet R',
#  'IDAutomationSC128L DEMO',
#  'Romantic',
#  'tvN Enjoystories',
#  'Gill Sans MT',
#  'ISOCTEUR',
#  'Franklin Gothic Heavy',
#  'RomanC',
#  'Arial',
#  'Javanese Text',
#  'Nanum Pen Script',
#  'Consolas',
#  'Corbel',
#  'SimSun-ExtB',
#  'Poor Richard',
#  'Gabriola',
#  'Rockwell',
#  'Century Schoolbook',
#  'SuperFrench',
#  'Corbel',
#  'Microsoft New Tai Lue',
#  'Book Antiqua',
#  'Syastro',
#  'Swis721 LtEx BT',
#  'ISOCT',
#  'Century Gothic',
#  'Dubai',
#  'Tw Cen MT',
#  'Century Gothic',
#  'Arial',
#  'Georgia',
#  'Bodoni MT',
#  'GreekS',
#  'HYGothic-Extra',
#  'Segoe UI Emoji',
#  'Vineta BT',
#  'SansSerif',
#  'Old English Text MT',
#  'Century Gothic',
#  'Perpetua',
#  'Arial',
#  'Yu Gothic',
#  'Vivaldi',
#  'S-Core Dream',
#  'Californian FB',
#  'Courier New',
#  'Segoe UI',
#  'Rockwell Extra Bold',
#  'Perpetua Titling MT',
#  'Symeteo',
#  'Vladimir Script',
#  'Perpetua',
#  'Arial',
#  'Noto Sans KR',
#  'Lucida Sans',
#  'Franklin Gothic Medium',
#  'PanRoman',
#  'Swis721 BT',
#  'Rockwell',
#  'Segoe UI',
#  'Monospac821 BT',
#  'Lucida Sans Typewriter',
#  'HYPost-Medium',
#  'Century Gothic',
#  'Swagger TTF',
#  'Playbill',
#  'RomanS',
#  'EuroRoman',
#  'Microsoft JhengHei',
#  'Bell MT',
#  'Bookman Old Style',
#  'Century Schoolbook',
#  'NanumSquareRound',
#  'S-Core Dream',
#  'Modern No. 20',
#  'Lucida Console',
#  'Swis721 BlkCn BT',
#  'GreekC',
#  'Lucida Console',
#  'Courier New',
#  'BM JUA_TTF',
#  'BankGothic Md BT',
#  'Segoe Script',
#  'Lucida Fax',
#  'Tw Cen MT',
#  'MT Extra',
#  'Yet R',
#  'Lucida Sans Typewriter',
#  'Colonna MT',
#  'Lucida Fax',
#  'Proxy 5',
#  'Segoe UI',
#  'Garamond',
#  'UniversalMath1 BT',
#  'Dubai',
#  'Forte',
#  'Elephant',
#  'Lucida Sans Unicode',
#  'MS Gothic',
#  'Gadugi',
#  'Pristina',
#  'Swis721 Lt BT',
#  'SimSun',
#  'ISOCPEUR',
#  'Century Schoolbook',
#  'Mistral',
#  'ItalicC',
#  'Parchment',
#  'Myanmar Text',
#  'Monospac821 BT',
#  'Proxy 8',
#  'Californian FB',
#  'Proxy 6',
#  'Nirmala UI',
#  'NanumSquare_ac',
#  'Code39  ',
#  'Gigi',
#  'SansSerif',
#  'Kunstler Script',
#  'Segoe UI',
#  'CommercialScript BT',
#  'Comic Sans MS',
#  'Batang',
#  'GothicG',
#  'Gigi',
#  'NanumMyeongjo',
#  'Free 3 of 9 Extended',
#  'Bookshelf Symbol 7',
#  'Eras Bold ITC',
#  'Tw Cen MT Condensed',
#  'Lucida Sans',
#  'Sitka Small',
#  'High Tower Text',
#  'Copperplate Gothic Light',
#  'Swis721 Ex BT',
#  'YiSunShin Dotum L',
#  'Copperplate Gothic Light',
#  'Dutch801 Rm BT',
#  'Monospac821 BT',
#  'Dutch801 Rm BT',
#  'Rockwell',
#  'Rage Italic',
#  'SansSerif',
#  'Rockwell Condensed',
#  'NanumGothicCoding',
#  'S-Core Dream',
#  'Myanmar Text',
#  'PanRoman',
#  'Monospac821 BT',
#  'Gill Sans MT Ext Condensed Bold',
#  'Swis721 Cn BT',
#  'Lucida Sans',
#  'Californian FB',
#  'Proxy 1',
#  'Monotxt',
#  'Perpetua',
#  'Harlow Solid Italic',
#  'Swis721 Blk BT',
#  'Yu Gothic',
#  'EuroRoman',
#  'Viner Hand ITC',
#  'Calibri',
#  'Comic Sans MS',
#  'Microsoft PhagsPa',
#  'Franklin Gothic Heavy',
#  'Blackadder ITC',
#  'Dutch801 Rm BT',
#  'Dubai',
#  'Rockwell',
#  'Calibri',
#  'Showcard Gothic',
#  'Arial Rounded MT Bold',
#  'NanumGothic Eco',
#  'Lucida Bright',
#  'HoloLens MDL2 Assets',
#  'Harlow Solid Italic',
#  'Ravie',
#  'Calibri',
#  'Wingdings',
#  'Century Schoolbook',
#  'Bodoni MT',
#  'Tempus Sans ITC',
#  'CityBlueprint',
#  'Goudy Old Style',
#  'Century Gothic',
#  'Proxy 9',
#  'NanumBarunGothic',
#  'Eras Medium ITC',
#  'Gill Sans MT',
#  'Segoe UI',
#  'Wingdings 2',
#  'NanumGothic',
#  'Microsoft Sans Serif',
#  'Segoe UI',
#  'GothicE',
#  'HYHeadLine-Medium',
#  'Segoe UI',
#  'Swis721 BdCnOul BT',
#  'ISOCPEUR',
#  'GDT',
#  'AMGDT',
#  'Trebuchet MS',
#  'Wingdings 2',
#  'Segoe UI',
#  'Leelawadee UI',
#  'French Script MT',
#  'Georgia',
#  'Edwardian Script ITC',
#  'Segoe UI',
#  'Sitka Small',
#  'Swis721 Lt BT',
#  'Gill Sans MT',
#  'Consolas',
#  'Constantia',
#  'Gloucester MT Extra Condensed',
#  'Noto Sans KR',
#  'Swis721 BT',
#  'Myanmar Text',
#  'Agency FB',
#  'Lucida Sans Typewriter',
#  'Century Schoolbook',
#  'Headline R',
#  'Leelawadee UI',
#  'Swis721 Cn BT',
#  'Leelawadee UI',
#  'Segoe Print',
#  'Romantic',
#  'Cambria',
#  'Dutch801 XBd BT',
#  'Baskerville Old Face',
#  'New Gulim',
#  'Franklin Gothic Book',
#  'Brush Script MT',
#  'Monotype Corsiva',
#  'Calibri',
#  'Engravers MT',
#  'RomanD',
#  'Sitka Small',
#  'Freestyle Script',
#  'NanumSquare_ac',
#  'Romantic',
#  'Corbel',
#  'Segoe UI',
#  'High Tower Text',
#  'Constantia',
#  'Eras Light ITC',
#  'Calisto MT',
#  'Segoe UI',
#  'Britannic Bold',
#  'Malgun Gothic',
#  'Italic',
#  'Microsoft JhengHei',
#  'Curlz MT',
#  'Franklin Gothic Demi Cond',
#  'Blackadder ITC',
#  'Consolas',
#  'Book Antiqua',
#  'Perpetua Titling MT',
#  'Malgun Gothic',
#  'Lucida Handwriting',
#  'AcadEref',
#  'Segoe UI Historic',
#  'Dutch801 XBd BT',
#  'ISOCTEUR',
#  'NanumMyeongjo Eco',
#  'Arial',
#  'Georgia',
#  'NanumSquare',
#  'HYMyeongJo-Extra',
#  'Segoe Script',
#  'Sitka Small',
#  'Georgia',
#  'NanumSquare',
#  'Gadugi',
#  'Lucida Fax',
#  'Bookman Old Style',
#  'Dutch801 Rm BT',
#  'Swis721 Ex BT',
#  'Swis721 BT',
#  'Bodoni MT',
#  'Berlin Sans FB Demi',
#  'BM EULJIRO',
#  'ISOCPEUR',
#  'Ebrima',
#  'Goudy Old Style',
#  'Noto Sans KR',
#  'Candara',
#  'Candara',
#  'Showcard Gothic',
#  'Sylfaen',
#  'Symbol',
#  'Ravie',
#  'Lucida Calligraphy',
#  'Gill Sans Ultra Bold',
#  'Syastro',
#  'Yu Gothic',
#  'Lucida Bright',
#  'Arial Rounded MT Bold',
#  'Arial',
#  'Proxy 9',
#  'Vineta BT',
#  'HYGraphic-Medium',
#  'Courier New',
#  'Elephant',
#  'NanumMyeongjo YetHangul',
#  'Javanese Text',
#  'Harrington',
#  'Monospac821 BT',
#  'Microsoft Tai Le',
#  'Verdana',
#  'Malgun Gothic',
#  'NanumMyeongjo',
#  'ScriptS',
#  'Ink Free',
#  'Informal Roman',
#  'Simplex',
#  'Malgun Gothic',
#  'KNPS Bandali',
#  'HYPMokGak-Bold',
#  'Lucida Bright',
#  'Lucida Calligraphy',
#  'NanumBarunpen',
#  'ISOCP',
#  'Californian FB',
#  'Goudy Old Style',
#  'Lucida Bright',
#  'Harrington',
#  'Sitka Small',
#  'ItalicT',
#  'Romantic',
#  'AmdtSymbols',
#  'Perpetua',
#  'Berlin Sans FB',
#  'Ghanachocolate',
#  'Calibri',
#  'Corbel',
#  'HYPMokGak-Bold',
#  'Corbel',
#  'Bodoni MT',
#  'Times New Roman',
#  'Swis721 BT',
#  'Snap ITC',
#  'Franklin Gothic Demi',
#  'Swis721 BT',
#  'Lucida Sans Typewriter',
#  'Lucida Bright',
#  'Segoe UI Emoji',
#  'Malgun Gothic',
#  'Gill Sans Ultra Bold',
#  'Technic',
#  'Century Schoolbook',
#  'Times New Roman',
#  'Perpetua',
#  'ISOCP3',
#  'Code 128',
#  'GDT',
#  'Yu Gothic',
#  'Bodoni MT',
#  'Arial',
#  'ISOCP',
#  'SansSerif',
#  'Microsoft PhagsPa',
#  'EuroRoman',
#  'ItalicT',
#  'Gill Sans Ultra Bold Condensed',
#  'Proxy 6',
#  'Gabriola',
#  'Txt',
#  'Malgun Gothic',
#  'Swis721 Cn BT',
#  'Footlight MT Light',
#  'Bodoni MT',
#  'Lucida Sans Typewriter',
#  'Book Antiqua',
#  'HYGungSo-Bold',
#  'HYPost-Light',
#  'Trebuchet MS',
#  'NanumBarunGothic',
#  'RomanT',
#  'Swis721 Lt BT',
#  'Franklin Gothic Demi Cond',
#  'SansSerif',
#  'Segoe Script',
#  'ISOCPEUR',
#  'MingLiU-ExtB',
#  'ISOCT',
#  'Microsoft JhengHei',
#  'Malgun Gothic',
#  'Microsoft PhagsPa',
#  'Verdana',
#  'ISOCP2',
#  'Microsoft YaHei',
#  'Pyunji R',
#  'Tw Cen MT',
#  'Cambria',
#  'Tahoma',
#  'Symbol',
#  'Jokerman',
#  'Tw Cen MT',
#  'Baskerville Old Face',
#  'Segoe UI',
#  'Perpetua',
#  'Webdings',
#  'Lucida Fax',
#  'Felix Titling',
#  'Swis721 Ex BT',
#  'Proxy 5',
#  'Algerian',
#  'Calibri',
#  'Wingdings 3',
#  'SansSerif',
#  'Gloucester MT Extra Condensed',
#  'Proxy 3',
#  'BM DoHyeon',
#  'Lucida Fax',
#  'Noto Sans KR',
#  'Constantia',
#  'Ami R',
#  'GENISO',
#  'Trebuchet MS',
#  'Century Schoolbook',
#  'Bernard MT Condensed',
#  'Georgia',
#  'Swis721 BT',
#  'Leelawadee UI',
#  'Bookman Old Style',
#  'Eras Bold ITC',
#  'Castellar',
#  'Segoe UI',
#  'Bell MT',
#  'HYPost-Light',
#  'Gill Sans MT',
#  'Verdana',
#  'KNPS Kkomi',
#  'Century Gothic',
#  'NanumGothic',
#  'RomanT',
#  'Monotxt',
#  'Consolas',
#  'Garamond',
#  'IDAutomationSC128XXL DEMO',
#  'Yu Gothic',
#  'Stylus BT',
#  'MoeumT R',
#  'Poor Richard',
#  'tvN Enjoystories',
#  'Berlin Sans FB Demi',
#  'Tw Cen MT Condensed Extra Bold',
#  'Complex',
#  'Arial',
#  'Courier New',
#  'Magneto',
#  'Dutch801 Rm BT',
#  'ItalicC',
#  'S-Core Dream',
#  'Nirmala UI',
#  'Perpetua',
#  'Swis721 LtCn BT',
#  'IDAutomationSC128XS DEMO',
#  'Gill Sans MT',
#  'Simplex',
#  'Candara',
#  'Dubai',
#  'Lucida Sans Typewriter',
#  'Garamond',
#  'BM YEONSUNG OTF',
#  'Imprint MT Shadow',
#  'Webdings',
#  'Swis721 Blk BT',
#  'Courier New',
#  'HYGothic-Medium',
#  'Malgun Gothic',
#  'Nanum BaReunJeongSin',
#  'Garamond',
#  'Calisto MT',
#  'ISOCT2',
#  'Symath',
#  'Calisto MT',
#  'Swis721 BdOul BT',
#  'Book Antiqua',
#  'Leelawadee UI',
#  'BankGothic Lt BT',
#  'Broadway',
#  'RomanC',
#  'Segoe UI',
#  'Tw Cen MT',
#  'Lucida Sans',
#  'Comic Sans MS',
#  'Ebrima',
#  'Cambria',
#  'Swis721 Cn BT',
#  'Segoe UI',
#  'Candara',
#  'Segoe UI Symbol',
#  'Swis721 Blk BT',
#  'Tw Cen MT Condensed',
#  'Trebuchet MS',
#  'BankGothic Md BT',
#  'Arial',
#  'Dubai',
#  'Palatino Linotype',
#  'Colonna MT',
#  'AIGDT',
#  'Comic Sans MS',
#  'Yu Gothic',
#  'Calisto MT',
#  'IDAutomationSC128S DEMO',
#  'Bodoni MT',
#  'Microsoft New Tai Lue',
#  'CityBlueprint',
#  'Times New Roman',
#  'SimSun',
#  'Microsoft YaHei',
#  'Stencil',
#  'Segoe UI',
#  'Candara',
#  'HYShortSamul-Medium',
#  'SuperFrench',
#  'Symeteo',
#  'Lucida Sans',
#  'Palatino Linotype',
#  'ISOCP2',
#  'MoeumT R',
#  'Bodoni MT',
#  'Gill Sans MT',
#  'Franklin Gothic Heavy',
#  'AcadEref',
#  'Impact',
#  'Symusic',
#  'Palatino Linotype',
#  'Nanum Brush Script',
#  'Georgia',
#  'S-Core Dream',
#  'Gill Sans MT Condensed',
#  'Swis721 Cn BT',
#  'Yu Gothic',
#  'Proxy 3',
#  'Californian FB',
#  'Tahoma',
#  'Agency FB',
#  'Niagara Solid',
#  'Niagara Engraved',
#  'Verdana',
#  'Matura MT Script Capitals',
#  'Palatino Linotype',
#  'Book Antiqua',
#  'AIGDT',
#  'Algerian',
#  'Snap ITC',
#  'Swis721 Ex BT',
#  'Britannic Bold',
#  'Georgia',
#  'Engravers MT',
#  'Wingdings 3',
#  'Constantia',
#  'Elephant',
#  'Gill Sans MT',
#  'ISOCP3',
#  'ISOCT3',
#  'Consolas',
#  'Palatino Linotype',
#  'Trebuchet MS',
#  'Lucida Fax',
#  'Bodoni MT',
#  'MS Reference Specialty',
#  'Bodoni MT',
#  'Eras Demi ITC',
#  'Calibri',
#  'MS Reference Sans Serif',
#  'Rockwell Condensed',
#  'Bookman Old Style',
#  'Times New Roman',
#  'Trebuchet MS',
#  'Candara',
#  'Monospac821 BT',
#  'MV Boli',
#  'Pyunji R',
#  'Eras Light ITC',
#  'Ebrima',
#  'Corbel',
#  'Proxy 4',
#  'Bookshelf Symbol 7',
#  'Franklin Gothic Medium',
#  'Berlin Sans FB',
#  'Stylus BT',
#  'NanumGothicCoding',
#  'Cambria',
#  'Segoe Script',
#  'Proxy 2',
#  'Segoe UI Symbol',
#  'S-Core Dream',
#  'Palace Script MT',
#  'Swis721 Cn BT',
#  'Franklin Gothic Medium Cond',
#  'Comic Sans MS',
#  'Romantic',
#  'S-Core Dream',
#  'Berlin Sans FB',
#  'Franklin Gothic Heavy',
#  'Lucida Sans Typewriter',
#  'ISOCTEUR',
#  'Microsoft JhengHei',
#  'MS Reference Sans Serif',
#  'Jokerman',
#  'Segoe Print',
#  'Century Schoolbook',
#  'HYMyeongJo-Extra',
#  'Book Antiqua',
#  'Consolas',
#  'Dutch801 Rm BT',
#  'Bahnschrift',
#  'Maiandra GD',
#  'NanumSquare_ac',
#  'IDAutomationSC128XL DEMO',
#  'Franklin Gothic Medium Cond',
#  'Marlett',
#  'Calibri',
#  'Palatino Linotype',
#  'Georgia',
#  'Segoe UI',
#  'Arial',
#  'Eras Demi ITC',
#  'Gill Sans MT Ext Condensed Bold',
#  'Constantia',
#  'Palatino Linotype',
#  'Sitka Small',
#  'Tw Cen MT',
#  'Microsoft Sans Serif',
#  'Dutch801 Rm BT',
#  'NanumBarunGothic',
#  'Kunstler Script',
#  'Bodoni MT',
#  'Bodoni MT',
#  'Trebuchet MS',
#  'GreekC',
#  'Tw Cen MT Condensed',
#  'Microsoft YaHei',
#  'Juice ITC',
#  'Courier New',
#  'Microsoft Tai Le',
#  'SimSun-ExtB',
#  'RomanD',
#  'Corbel',
#  'Headline R',
#  'Calisto MT',
#  'Dutch801 Rm BT',
#  'CommercialScript BT',
#  'Niagara Engraved',
#  'Cooper Black',
#  'Gill Sans Ultra Bold Condensed',
#  'Bell MT',
#  'Bernard MT Condensed',
#  'Bell MT',
#  'Franklin Gothic Book',
#  'Tw Cen MT',
#  'NanumSquareRound',
#  'Tahoma',
#  'Tempus Sans ITC',
#  'Swis721 LtCn BT',
#  'Pristina',
#  'Bookman Old Style',
#  'Bodoni MT',
#  'Symap',
#  'Tw Cen MT Condensed Extra Bold',
#  'ISOCT2',
#  'Bahnschrift',
#  'Pyunji R',
#  'Papyrus',
#  'Microsoft PhagsPa',
#  'Segoe UI',
#  'Dubai',
#  'Consolas',
#  'ISOCTEUR',
#  'IDAutomationSC128XXS DEMO',
#  'Segoe UI',
#  'NanumSquareRound',
#  'Verdana',
#  'Verdana',
#  'ScriptC',
#  'Constantia',
#  'Californian FB',
#  'Bodoni MT',
#  'Complex',
#  'Gulim',
#  'Calisto MT',
#  'Vivaldi',
#  'Bradley Hand ITC',
#  'Goudy Stout',
#  'Onyx',
#  'Swis721 BdCnOul BT',
#  'Comic Sans MS',
#  'Corbel',
#  'Book Antiqua',
#  'Swis721 LtCn BT',
#  'Lucida Bright',
#  'Stencil',
#  'ScriptC',
#  'Nirmala UI',
#  'Script MT Bold',
#  'Swis721 LtCn BT',
#  'Times New Roman',
#  'Palatino Linotype',
#  'Microsoft Himalaya',
#  'Gill Sans MT Condensed',
#  'NanumSquareRound',
#  'Swis721 BlkEx BT',
#  'Rockwell Condensed',
#  'Century Gothic',
#  'Myanmar Text',
#  'Mistral',
#  'TechnicLite',
#  'Informal Roman',
#  'Microsoft Yi Baiti',
#  'GothicG',
#  'Haettenschweiler',
#  'Noto Sans KR',
#  'CommercialPi BT',
#  'Bodoni MT',
#  'Goudy Stout',
#  'HYGothic-Medium',
#  'Constantia',
#  'AMGDT',
#  'Parchment',
#  'Dubai',
#  'Nirmala UI',
#  'S-Core Dream',
#  'Magic R',
#  'Swis721 Cn BT',
#  'Juice ITC',
#  'Monospac821 BT',
#  'CommercialPi BT',
#  'Swis721 Cn BT',
#  'Franklin Gothic Medium',
#  'Perpetua Titling MT',
#  'OCR A Extended',
#  'Cambria',
#  'Swis721 Lt BT',
#  'Magneto',
#  'Cooper Black',
#  'Bookman Old Style',
#  'Txt',
#  'Bell MT',
#  'MS Reference Specialty',
#  'Microsoft YaHei',
#  'GothicE',
#  'Swis721 BT',
#  'Microsoft YaHei',
#  'Candara',
#  'Wingdings',
#  'EuroRoman',
#  'Bodoni MT',
#  'High Tower Text',
#  'GothicI',
#  'Modern No. 20',
#  'NanumSquare',
#  'Rockwell',
#  'Franklin Gothic Demi',
#  'Goudy Old Style',
#  'Tw Cen MT Condensed',
#  'Niagara Solid',
#  'Bodoni MT',
#  'Rockwell Extra Bold',
#  'Candara',
#  'Palace Script MT',
#  'Consolas',
#  'Perpetua',
#  'Swis721 BdOul BT',
#  'Segoe Print',
#  'Sitka Small',
#  'Proxy 1',
#  'Copperplate Gothic Bold',
#  'Bodoni MT',
#  'Microsoft JhengHei',
#  'Bookman Old Style',
#  'GothicI',
#  'Franklin Gothic Demi',
#  'Swis721 BlkCn BT',
#  'Constantia',
#  'Corbel',
#  'Goudy Old Style',
#  'Garamond',
#  'Segoe UI',
#  'Franklin Gothic Book',
#  'Rockwell',
#  'SansSerif',
#  'S-Core Dream',
#  'Verdana',
#  'Romantic',
#  'Proxy 4',
#  'Franklin Gothic Demi',
#  'ISOCT3',
#  'Calibri',
#  'Technic',
#  'Playbill',
#  'Lucida Sans Typewriter',
#  'Segoe MDL2 Assets',
#  'Candara',
#  'Rage Italic',
#  'Arial',
#  'Microsoft Himalaya',
#  'Arial',
#  'Matura MT Script Capitals',
#  'Rockwell Condensed',
#  'Arial',
#  'Symap',
#  'Wide Latin',
#  ...]

# %%
plt.plot(x, y)
plt.title('꺽은선 그래프')
# Out:
# Text(0.5, 1.0, '꺽은선 그래프')

# %%
plt.plot([-1, 0, 1], [-5, -1, 2])
