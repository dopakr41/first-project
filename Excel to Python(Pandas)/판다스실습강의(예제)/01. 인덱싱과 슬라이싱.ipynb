# %%
import pandas as pd

df1 = pd.read_excel("E09EXAMPLE.xlsx", skiprows=1)
df1
# Out:
#     Unnamed: 0    년도  팀수  경기수         1위              2위           3위  \
# 0          NaN  1930  13   18    Uruguay       Argentina          USA
# 1          NaN  1934  16   17      Italy  Czechoslovakia      Germany
# 2          NaN  1938  15   18      Italy         Hungary       Brazil
# 3          NaN  1950  13   22    Uruguay          Brazil       Sweden
# 4          NaN  1954  16   26    Germany         Hungary      Austria
# 5          NaN  1958  16   35     Brazil          Sweden       France
# 6          NaN  1962  16   32     Brazil  Czechoslovakia        Chile
# 7          NaN  1966  16   32    England         Germany     Portugal
# 8          NaN  1970  16   32     Brazil           Italy      Germany
# 9          NaN  1974  16   38    Germany     Netherlands       Poland
# 10         NaN  1978  16   38  Argentina     Netherlands       Brazil
# 11         NaN  1982  24   52      Italy         Germany       Poland
# 12         NaN  1986  24   52  Argentina         Germany       France
# 13         NaN  1990  24   52    Germany       Argentina        Italy
# 14         NaN  1994  24   52     Brazil           Italy       Sweden
# 15         NaN  1998  32   64     France          Brazil      Croatia
# 16         NaN  2002  32   64     Brazil         Germany       Turkey
# 17         NaN  2006  32   64      Italy          France      Germany
# 18         NaN  2010  32   64      Spain     Netherlands      Germany
# 19         NaN  2014  32   64    Germany       Argentina  Netherlands
#
#                 4위    골        관중수           개최국  Unnamed: 11  \
# 0       Yugoslavia   70    590.549       Uruguay          NaN
# 1          Austria   70        363         Italy          NaN
# 2           Sweden   84      375.7        France          NaN
# 3            Spain   88  1.045.246        Brazil          NaN
# 4          Uruguay  140    768.607   Switzerland          NaN
# 5          Germany  126     819.81        Sweden          NaN
# 6       Yugoslavia   89    893.172         Chile          NaN
# 7     Soviet Union   89  1.563.135       England          NaN
# 8          Uruguay   95  1.603.975        Mexico          NaN
# 9           Brazil   97  1.865.753       Germany          NaN
# 10           Italy  102  1.545.791     Argentina          NaN
# 11          France  146  2.109.723         Spain          NaN
# 12         Belgium  132  2.394.031        Mexico          NaN
# 13         England  115  2.516.215         Italy          NaN
# 14        Bulgaria  141  3.587.538           USA          NaN
# 15     Netherlands  171  2.785.100        France          NaN
# 16  Korea Republic  161  2.705.197   Korea/Japan          NaN
# 17        Portugal  147  3.359.439       Germany          NaN
# 18         Uruguay  145  3.178.856  South Africa          NaN
# 19          Brazil  171  3.386.810        Brazil          NaN
#
#              Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15  Unnamed: 16  \
# 0                    NaN         NaN         NaN         NaN          NaN
# 1   좌측 표는 역대 월드컵대회의 자료이다         NaN         NaN         NaN          NaN
# 2                  좌측 표를         NaN         NaN         NaN          NaN
# 3                    NaN         NaN         NaN         NaN          NaN
# 4                    NaN         NaN         NaN         NaN          NaN
# 5                     년도         개최국          1위          2위           3위
# 6                   1930     Uruguay     Uruguay   Argentina          USA
# 7                    ...         ...         ...         ...          ...
# 8                   2014      Brazil     Germany   Argentina  Netherlands
# 9                    NaN         NaN         NaN         NaN          NaN
# 10                   NaN         NaN         NaN         NaN          NaN
# 11  이런 형식의 데이터프레임으로 추출하라         NaN         NaN         NaN          NaN
# 12                   NaN         NaN         NaN         NaN          NaN
# 13                   NaN         NaN         NaN         NaN          NaN
# 14                   NaN         NaN         NaN         NaN          NaN
# 15                   NaN         NaN         NaN         NaN          NaN
# 16                   NaN         NaN         NaN         NaN          NaN
# 17                   NaN         NaN         NaN         NaN          NaN
# 18                   NaN         NaN         NaN         NaN          NaN
# 19                   NaN         NaN         NaN         NaN          NaN
#
#    Unnamed: 17
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5           4위
# 6   Yugoslavia
# 7          ...
# 8       Brazil
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN

# %%
df1 = df1.loc[:,"년도":"개최국"]
df1.iloc[:,[0, 9, 3, 4, 5, 6]].to_clipboard(index=False)

# %% [markdown]
# # 전체코드

# %%
import pandas as pd

df1 = pd.read_excel("E09EXAMPLE.xlsx", skiprows=1)
df1 = df1.loc[0:19, "년도":"개최국"]
df1.iloc[:, [0, 9, 3, 4, 5, 6]].to_clipboard(index=False)
